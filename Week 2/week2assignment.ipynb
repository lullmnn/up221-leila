# %%
import pandas as pd
import geopandas as gpd

# %%
# read and add file to notebook
waymo = gpd.read_file('SGO-2021-01_Incident_Reports_ADS.csv')

# %%
# what's the data type?
type(waymo)
# Out:
# pandas.core.frame.DataFrame

# %%
waymo.head()
# Out:
#     Report ID Report Version Reporting Entity Report Type Report Month  \
# 0  30270-9437              1        Waymo LLC     Monthly           11
# 1  30270-9436              1        Waymo LLC     Monthly           11
# 2  30270-9435              1        Waymo LLC     Monthly           11
# 3  30270-9434              1        Waymo LLC     Monthly           11
# 4  30270-9433              1        Waymo LLC     Monthly           11
#
#   Report Year Report Submission Date          VIN VIN - Unknown Serial Number  \
# 0        2024               DEC-2024  SADHW2S10M1                         N/A
# 1        2024               DEC-2024  SADHW2S12R1                         N/A
# 2        2024               DEC-2024  SADHW2S12R1                         N/A
# 3        2024               DEC-2024  SADHW2S15R1                         N/A
# 4        2024               DEC-2024  SADHW2S11R1                         N/A
#
#      Make   Model Model - Unknown Model Year Model Year - Unknown  \
# ...

# %%
# try tail()
waymo.tail(1)
# Out:
#      Report ID Report Version Reporting Entity Report Type Report Month  \
# 1690   30270-1              1        Waymo LLC       1-Day
#
#      Report Year Report Submission Date          VIN VIN - Unknown  \
# 1690                           JUL-2021  2C4RC1K76HR
#
#      Serial Number      Make     Model Model - Unknown Model Year  \
# 1690                Chrysler  Pacifica                       2017
#
#      Model Year - Unknown  Same Vehicle ID Mileage Mileage - Unknown  \
# 1690                       27a8308e4525a57   34996
#
#               Driver / Operator Type ADAS/ADS System Version  \
# 1690  In-Vehicle (Commercial / Test)      4th Generation ADS
#
#      ADAS/ADS System Version - Unk ADAS/ADS System Version CBI  \
# 1690
#
#      ADAS/ADS Hardware Version ADAS/ADS Hardware Version - Unk  \
# 1690
#
#      ADAS/ADS Hardware Version CBI ADAS/ADS Software Version  \
# 1690
#
#      ADAS/ADS Software Version - Unk ADAS/ADS Software Version CBI  \
# 1690
#
# ...

# %%
waymo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1691 entries, 0 to 1690
# Columns: 137 entries, Report ID to Narrative - CBI?
# dtypes: object(137)
# memory usage: 1.8+ MB

# %%
waymo.columns.to_list()
# Out:
# ['Report ID',
#  'Report Version',
#  'Reporting Entity',
#  'Report Type',
#  'Report Month',
#  'Report Year',
#  'Report Submission Date',
#  'VIN',
#  'VIN - Unknown',
#  'Serial Number',
#  'Make',
#  'Model',
#  'Model - Unknown',
#  'Model Year',
#  'Model Year - Unknown',
#  'Same Vehicle ID',
#  'Mileage',
#  'Mileage - Unknown',
#  'Driver / Operator Type',
#  'ADAS/ADS System Version',
#  'ADAS/ADS System Version - Unk',
#  'ADAS/ADS System Version CBI',
#  'ADAS/ADS Hardware Version',
#  'ADAS/ADS Hardware Version - Unk',
#  'ADAS/ADS Hardware Version CBI',
#  'ADAS/ADS Software Version',
#  'ADAS/ADS Software Version - Unk',
#  'ADAS/ADS Software Version CBI',
#  'Other Reporting Entities?',
#  'Other Reporting Entities? - Unk',
#  'Other Reporting Entities? - NA',
#  'Federal Regulatory Exemption?',
#  'Other Federal Reg. Exemption',
#  'Federal Reg. Exemption - Unk',
#  'Federal Reg. Exemption - No',
#  'State or Local Permit?',
#  'State or Local Permit',
# ...

# %%
# single column for city
waymo['City'].sample(5)
# Out:
# 337      Los Angeles
# 112    San Francisco
# 671    San Francisco
# 662    San Francisco
# 129        Streetman
# Name: City, dtype: object

# %%
# single column for latitude
waymo['Latitude'].sample(5)
# Out:
# 1610    [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 1496    [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 527     [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 1533    [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 1655    [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# Name: Latitude, dtype: object

# %%
# single column for Longitude
waymo['Longitude'].sample(5)
# Out:
# 438     [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 1299    [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 282     [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 1668    [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 1381    [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# Name: Longitude, dtype: object

# %%
# single column for Address
waymo['Address'].sample(5)
# Out:
# 1218    [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 505     [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 780     [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 1511    [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 65      [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# Name: Address, dtype: object

# %%
# how many rows and columns?
waymo.shape
# Out:
# (1691, 137)

# %%
# find how many cities are represented in this data
waymo['City'].value_counts()
# Out:
# City
# San Francisco                901
# Phoenix                      130
# Tempe                        100
# Austin                        95
# Los Angeles                   72
#                             ...
# Los Angelas                    1
# Sann Francisco                 1
# Sunnyvale                      1
# Mammoth                        1
# Yellowstone National Park      1
# Name: count, Length: 103, dtype: int64

# %%
# save it as a variable
city_count = waymo['City'].value_counts()
city_count
# Out:
# City
# San Francisco                901
# Phoenix                      130
# Tempe                        100
# Austin                        95
# Los Angeles                   72
#                             ...
# Los Angelas                    1
# Sann Francisco                 1
# Sunnyvale                      1
# Mammoth                        1
# Yellowstone National Park      1
# Name: count, Length: 103, dtype: int64

# %%
# converting the series into a dataframe
city_count = city_count.reset_index()
city_count
# Out:
#                           City  count
# 0                San Francisco    901
# 1                      Phoenix    130
# 2                        Tempe    100
# 3                       Austin     95
# 4                  Los Angeles     72
# ..                         ...    ...
# 98                 Los Angelas      1
# 99              Sann Francisco      1
# 100                  Sunnyvale      1
# 101                    Mammoth      1
# 102  Yellowstone National Park      1
#
# [103 rows x 2 columns]

# %%
type(waymo['City'])
# Out:
# pandas.core.series.Series

# %%
# current columns as a list
city_count.columns.to_list()
# Out:
# ['City', 'count']

# %%
# Make a bar chart
city_count.plot.bar(x = 'City', y = 'count', title = 'Cities represented in the dataset')
# Out:
# <Axes: title={'center': 'Cities represented in the dataset'}, xlabel='City'>

# %%
# output the original data's info
waymo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1691 entries, 0 to 1690
# Columns: 137 entries, Report ID to Narrative - CBI?
# dtypes: object(137)
# memory usage: 1.8+ MB

# %%
# show a dataframe with a subset of columns
waymo[['Reporting Entity','Incident Date','Driver / Operator Type','ADS Equipped?','Narrative']]
# Out:
#                    Reporting Entity Incident Date  \
# 0                         Waymo LLC      NOV-2024
# 1                         Waymo LLC      NOV-2024
# 2                         Waymo LLC      NOV-2024
# 3                         Waymo LLC      NOV-2024
# 4                         Waymo LLC      NOV-2024
# ...                             ...           ...
# 1686                      Waymo LLC      JUL-2021
# 1687  Transdev Alternative Services      JUL-2021
# 1688                      Waymo LLC      JUL-2021
# 1689  Transdev Alternative Services      JUL-2021
# 1690                      Waymo LLC      JUL-2021
#
#               Driver / Operator Type ADS Equipped?  \
# 0                               None           Yes
# 1                               None           Yes
# 2                               None           Yes
# 3                               None           Yes
# 4                               None           Yes
# ...

# %%
# list of desired column names
desired_columns = ['Reporting Entity','Incident Date','ADS Equipped?','City','Narrative']

# subset based on desired columns
waymo[desired_columns].sample(5)
# Out:
#          Reporting Entity Incident Date ADS Equipped?           City  \
# 928             Waymo LLC      JUN-2023           Yes  San Francisco
# 1279           Zoox, Inc.      AUG-2022           Yes  San Francisco
# 344             Waymo LLC      JUL-2024           Yes  San Francisco
# 322            Zoox, Inc.      AUG-2024           Yes  Spring Valley
# 931   General Motors, LLC      JUN-2023           Yes  San Francisco
#
#                                               Narrative
# 928   On June [XXX], 2023 at 12:53 PM PT a Waymo Aut...
# 1279  A Zoox vehicle in autonomy was proceeding stra...
# 344   On July [XXX], 2024 at 2:21 PM PT a Waymo Auto...
# 322   A Zoox vehicle in autonomous mode was travelin...
# 931   On July 14, 2023, GM Cruise Holdings LLC ("Cru...

# %%
# make a new data table with just the desired columns
waymo_trimmed = waymo[desired_columns].copy()
waymo_trimmed
# Out:
#                    Reporting Entity Incident Date ADS Equipped?  \
# 0                         Waymo LLC      NOV-2024           Yes
# 1                         Waymo LLC      NOV-2024           Yes
# 2                         Waymo LLC      NOV-2024           Yes
# 3                         Waymo LLC      NOV-2024           Yes
# 4                         Waymo LLC      NOV-2024           Yes
# ...                             ...           ...           ...
# 1686                      Waymo LLC      JUL-2021           Yes
# 1687  Transdev Alternative Services      JUL-2021           Yes
# 1688                      Waymo LLC      JUL-2021           Yes
# 1689  Transdev Alternative Services      JUL-2021           Yes
# 1690                      Waymo LLC      JUL-2021           Yes
#
#                City                                          Narrative
# 0     San Francisco  On November [XXX], 2024 at 4:22 PM PT a Waymo ...
# ...

# %%
waymo_trimmed[waymo_trimmed.City == 'Los Angeles']
# Out:
#                    Reporting Entity Incident Date ADS Equipped?         City  \
# 2                         Waymo LLC      NOV-2024           Yes  Los Angeles
# 5                         Waymo LLC      NOV-2024           Yes  Los Angeles
# 11                        Waymo LLC      NOV-2024           Yes  Los Angeles
# 17                        Waymo LLC      DEC-2024           Yes  Los Angeles
# 26                        Waymo LLC      NOV-2024           Yes  Los Angeles
# ...                             ...           ...           ...          ...
# 1054  Transdev Alternative Services      MAR-2023           Yes  Los Angeles
# 1064                      Waymo LLC      MAR-2023           Yes  Los Angeles
# 1478         Mercedes-Benz USA, LLC      MAR-2022           Yes  Los Angeles
# 1494              Robert Bosch, LLC      MAR-2022           Yes  Los Angeles
# 1497         Mercedes-Benz USA, LLC      MAR-2022           Yes  Los Angeles
#
# ...

# %%
# I would like to plot this data but unfortunately the latitude and longitude have been redacted from this dataset, as can be seen above.
